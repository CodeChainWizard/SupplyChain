# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../data/processed/demand_data.csv")

# %%
print(data.info())
print(data.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   date                10 non-null     object
#  1   product_id          10 non-null     int64
#  2   location_id         10 non-null     int64
#  3   demand              10 non-null     int64
#  4   price               10 non-null     float64
#  5   rolling_avg_demand  6 non-null      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 612.0+ bytes
# None
#        product_id  location_id      demand      price  rolling_avg_demand
# count   10.000000    10.000000   10.000000  10.000000            6.000000
# mean   101.500000     1.500000  122.500000  10.930000          122.445000
# std      0.527046     0.527046   39.972907   1.390484           41.258881
# min    101.000000     1.000000   80.000000   9.200000           82.330000
# 25%    101.000000     1.000000   85.750000   9.725000           85.920000
# 50%    101.500000     1.500000  120.000000  10.900000          120.835000
# 75%    102.000000     2.000000  158.750000  12.225000          160.002500
# max    102.000000     2.000000  170.000000  12.500000          163.330000

# %%
sns.lineplot(data=data, x="date", y="demand")
plt.title("Demand Over Time")
plt.show()

# %%
missing_values = data.isnull().sum()
print("Missing Values:\n", missing_values)
# Out:
# Missing Values:
#  date                  0
# product_id            0
# location_id           0
# demand                0
# price                 0
# rolling_avg_demand    4
# dtype: int64
